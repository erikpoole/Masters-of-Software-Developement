# %% [markdown]
# # Part 1: A/B Hypothesis testing

# %% [markdown]
# **Null Hypothesis = there is no difference between groups A & B**
#
# **aClicks/aViews - bClicks/bViews = 0**

# %%
import scipy as sc
from scipy.stats import norm

# %%
aViews = 1000
aClicks = 500

bViews = 1000
bClicks = 550

# %%
aProportion = aClicks / aViews
bProportion = bClicks / bViews

aSTD = sc.sqrt(aProportion * (1-aProportion)/aViews)
bSTD = sc.sqrt(bProportion * (1-bProportion)/bViews)

# %%
# print(aProportion)
# print(bProportion)
# print(aSTD)
# print(bSTD)

# %%
pHat = (aViews*aProportion) / (aViews+bViews) + (bViews*bProportion) / (aViews+bViews)
qHat = 1-pHat

# %%
# print(pHat)
# print(qHat)

# %%
z = (aProportion - bProportion) / sc.sqrt(pHat*qHat*(1/aViews + 1/bViews))

# not 1-(norm.cfc(z)) because we're checking to see if z value is outlandish (not in the normal distribution)
p = norm.cdf(z)

print(norm.cdf(1))
# Out:
# 0.8413447460685429

# %%
print("z: ", z)
print("p: ", p)
# Out:
# z:  -2.238868314198227
# p:  0.012582242850159199

# %% [markdown]
# **At a 5% confidence threshold the null hypothesis is overturned!
# The two logos produce different results (we'd expect that logo b is outperforming logo a...)**
#
# **We are close but not quite beating the 1% confidence threshold, the null hypothesis is not overturned...**

# %% [markdown]
# # Part 2: Regression of real estate data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.formula.api as sm

# %%
importFrame1 = pd.read_csv("realEstate1.csv")
importFrame2 = pd.read_csv("realEstate2.csv")

# %%
baseSet = pd.concat([importFrame1, importFrame2])

# %%
# print(list(dataset))
reducedColsSet = baseSet[['Acres', 'Deck', 'GaragCap', 'Latitude', 'Longitude', 'LstPrice', 'Patio', 'PkgSpacs', 'PropType', 'SoldPrice', 'Taxes', 'TotBed', 'TotBth', 'TotSqf', 'YearBlt']]

filteredSet = reducedColsSet[(reducedColsSet.LstPrice >= 200000) & (reducedColsSet.LstPrice <= 1000000)]
filteredSet = filteredSet[(filteredSet.Longitude < -100) & (filteredSet.Longitude > -120)]
filteredSet = filteredSet[(filteredSet.Taxes < 20000)]

filteredSet['TotSqf'] = pd.to_numeric(filteredSet['TotSqf'].str.replace(',', ''))

propTypeList = [];
for i in filteredSet['PropType']:
    if i == "Single Family":
        propTypeList.append(1);
    else:
        propTypeList.append(0);

filteredSet.insert(len(filteredSet.columns), "Prop_Type_num", propTypeList)

# print(filteredSet)

# %% [markdown]
# **There are 260 rows and 16 columns in the dataset.
# No remaining values seem unreasonable at a glance, though it's possible more will be discovered as I go forward.**

# %%
houseTypeSet = filteredSet['PropType'].value_counts().plot.bar()

# %%
fig, ax = plt.subplots()
im = ax.pcolor(filteredSet.corr(), vmin=-1, vmax=1)
cbar = fig.colorbar(im)

plt.xticks(np.arange(0, len(filteredSet.columns), 1.0));
plt.yticks(np.arange(0, len(filteredSet.columns), 1.0));

# %%
pd.plotting.scatter_matrix(filteredSet \
[['Acres', 'LstPrice', 'SoldPrice', 'Taxes', 'TotBed', 'TotBth', 'TotSqf', 'YearBlt']], \
figsize=(20,20));

# %% [markdown]
# **At a glance there seems to be a strong correlation between list price, sold price, and taxes which makes intuitive sense.  Those three also seem to share a strong relationship with total square feet.  Beds and baths also seem to have a more or less linear relationship to the price.**

# %%
ax = filteredSet.plot.scatter('Longitude', 'Latitude', c='SoldPrice', colormap='jet', sharex=False);
ax.set_xticks(np.arange(np.round(filteredSet['Longitude'].min(), decimals=2), filteredSet['Longitude'].max(), .01))
plt.xticks(rotation=45);

# %% [markdown]
# **The price seems to increase as you move northeast - towards downtown and the University of Utah.**

# %%
soldPriceOLS = sm.ols(formula="SoldPrice ~ LstPrice", data=filteredSet).fit()

print("R-Squared: ", soldPriceOLS.rsquared.round(4))
print("LstPrice coefficient: ", soldPriceOLS.params.LstPrice.round(4))

fig, ax = plt.subplots()
filteredSet.plot.scatter(x='LstPrice', y='SoldPrice', ax=ax)
filteredSet.assign(fit=soldPriceOLS.fittedvalues).plot(x='LstPrice', y='fit', ax=ax, c='red');

# soldPriceOLS.summary()
# Out:
# R-Squared:  0.9902
# LstPrice coefficient:  0.9441

# %% [markdown]
# **The beta_1 value is the coefficient (.9441) that relates Sold Price and List Price. As the List Price increases by .9902, this model predicts that the Sold Price will increase by 1.**

# %%
soldPriceOLS_ALL = sm.ols(formula="SoldPrice ~ \
Acres + Deck + GaragCap + Latitude + Longitude + Patio + PkgSpacs + \
Taxes + TotBed + TotBth + TotSqf + YearBlt", data=filteredSet).fit()

print("ALL")
print("R-Squared: ", soldPriceOLS_ALL.rsquared.round(4), '\n')
print(soldPriceOLS_ALL.pvalues.round(4))
# Out:
# ALL
# R-Squared:  0.8532
#
# Intercept    0.0415
# Acres        0.2875
# Deck         0.2717
# GaragCap     0.0006
# Latitude     0.1961
# Longitude    0.0005
# Patio        0.5691
# PkgSpacs     0.6396
# Taxes        0.0000
# TotBed       0.1126
# TotBth       0.4029
# TotSqf       0.0000
# YearBlt      0.2264
# dtype: float64

# %%
soldPriceOLS_REDUCED1 = sm.ols(formula="SoldPrice ~ \
Acres + Deck + GaragCap + Latitude + Longitude + \
Taxes + TotBed + TotBth + TotSqf + YearBlt", data=filteredSet).fit()

print("ALL")
print("R-Squared: ", soldPriceOLS_REDUCED1.rsquared.round(4), '\n')
print(soldPriceOLS_REDUCED1.pvalues.round(4))
# Out:
# ALL
# R-Squared:  0.8529
#
# Intercept    0.0521
# Acres        0.2899
# Deck         0.2946
# GaragCap     0.0007
# Latitude     0.1410
# Longitude    0.0005
# Taxes        0.0000
# TotBed       0.1152
# TotBth       0.3638
# TotSqf       0.0000
# YearBlt      0.2023
# dtype: float64

# %%
soldPriceOLS_REDUCED2 = sm.ols(formula= \
"SoldPrice ~ GaragCap + Latitude + Longitude + Taxes + TotBed + TotSqf + YearBlt", data=filteredSet).fit()

print("ALL")
print("R-Squared: ", soldPriceOLS_REDUCED2.rsquared.round(4), '\n')
print(soldPriceOLS_REDUCED2.pvalues.round(4))
# Out:
# ALL
# R-Squared:  0.8513
#
# Intercept    0.0956
# GaragCap     0.0005
# Latitude     0.0250
# Longitude    0.0003
# Taxes        0.0000
# TotBed       0.0589
# TotSqf       0.0000
# YearBlt      0.2424
# dtype: float64

# %%
soldPriceOLS_FINAL = sm.ols(formula= \
"SoldPrice ~ GaragCap + Longitude + Taxes + TotSqf", data=filteredSet).fit()

print("ALL")
print("R-Squared: ", soldPriceOLS_FINAL.rsquared.round(4), '\n')
print(soldPriceOLS_FINAL.pvalues.round(4))
# Out:
# ALL
# R-Squared:  0.8447
#
# Intercept    0.0001
# GaragCap     0.0011
# Longitude    0.0001
# Taxes        0.0000
# TotSqf       0.0000
# dtype: float64

# %% [markdown]
# **The best three predictors of sold price are Garage Capacity, Longitude, Taxes, and Total Square Feet.  I would have originally dropped Garage Capacity off as well, since the loss in R-Squared was minimal, but the questions later seem to indicate I should keep it...**

# %%
soldPriceOLS_FINAL.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SoldPrice   R-squared:                       0.845
# Model:                            OLS   Adj. R-squared:                  0.842
# Method:                 Least Squares   F-statistic:                     346.8
# Date:                Wed, 22 May 2019   Prob (F-statistic):          8.05e-102
# Time:                        14:17:30   Log-Likelihood:                -3286.6
# No. Observations:                 260   AIC:                             6583.
# Df Residuals:                     255   BIC:                             6601.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.628e+08    4.1e+07      3.974      0.000    8.21e+07    2.44e+08
# ...

# %% [markdown]
# **Specific questions:**
#
# **Often the price per square foot for a house is advertised. Is this what the coefficient for TotSqf is measuring? Provide an interpretation for the coefficient for TotSqf.**
# Kind of, this coefficient shows the relationship between the square footage of the house and total cost.  For every square foot added the total cost increases by $64.23.  However, the total cost of the house is also based on our other significant factors.  So the relationship there, but this isn't the same as taking the total cost of the house and just dividing it by the number of square feet.
#
# **Estimate the value that each Garage space adds to a house.**
# The GaragCap coefficient is 21120.  This model predicts that every garage space in a house increases the cost by $21,120.
#
# **Does latitude or longitude have an impact on house price? Explain.**
# I eventually ruled out latitude as a significant factor, but longitude remained.  Apparently moving East->West (probably closer to the mountains and those excellent mountain views) matters more than being futher North.
#
# **If we wanted to start a 'house flipping' company, we'd have to be able to do a better job of predicting the sold price than the list price does. How does your model compare?**
# Not particularly favorably.  Since the list price has a R-Squared value of 0.9902 and our model has one of 0.8447 we're going to guess wrong about 15% more of the time.  The list price would be hard to beat!

# %%
# print(filteredSet.dtypes)
# houseTypeSet.describe()
# print(houseTypeSet)
# df.groupby([df.index.date, 'action']).count()
